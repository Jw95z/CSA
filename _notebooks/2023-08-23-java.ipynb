// %% [markdown]
// ---
// layout: post
// title: First java notebook
// description: hello world
// toc: true
// permalink: /javahello
// comments: true
// categories: [5.A, C4.1]
// type: hacks
// course: {csa: {week: 1}}
// ---

// %% [markdown]
// ## Hello

// %%
public class HelloStatic {
    // Java standard runtime entry point
    public static void main(String[] args) {
        System.out.println("Hello World!");
    }
}
// A method call allows us to execute code that is wrapped in Class
HelloStatic.main(null);   // Class prefix allows reference of Static Method
// Out:
// Hello World!

// %%
public class InsertionSort {
    public static void main(String[] args) {
        int[] arr = {5, 2, 9, 3, 6};
        insertionSort(arr);
        System.out.println("Sorted Array:");
        for (int num : arr) {
            System.out.print(num + " ");
        }
    }

    public static void insertionSort(int[] arr) {
        int n = arr.length;
        for (int i = 1; i < n; i++) {
            int key = arr[i];
            int j = i - 1;

            while (j >= 0 && arr[j] > key) {
                arr[j + 1] = arr[j];
                j--;
            }

            arr[j + 1] = key;
        }
    }
}
InsertionSort.main(null);
// Out:
// Sorted Array:
// 2 3 5 6 9

// %%
public class SelectionSort {
    public static void main(String[] args) {
        int[] arr = {5, 2, 9, 3, 6};
        selectionSort(arr);
        System.out.println("Sorted Array:");
        for (int num : arr) {
            System.out.print(num + " ");
        }
    }

    public static void selectionSort(int[] arr) {
        int n = arr.length;
        for (int i = 0; i < n - 1; i++) {
            int minIndex = i;
            for (int j = i + 1; j < n; j++) {
                if (arr[j] < arr[minIndex]) {
                    minIndex = j;
                }
            }
            // Swap arr[i] and arr[minIndex]
            int temp = arr[i];
            arr[i] = arr[minIndex];
            arr[minIndex] = temp;
        }
    }
}
SelectionSort.main(null);
// Out:
// Sorted Array:
// 2 3 5 6 9

// %%
import java.util.Scanner;
public class Bingo {
    public String line = "";
    public String straight = "";
    public static void board(String[][] bingos, int dimensions) {
        String line = "";
        String straight = "";
        for(int z = 0; z < dimensions; z++) {
            
            line += " _";
            
        }
        System.out.println(line);
        for(int j = 0; j < dimensions; j++) {
            straight += "|";
            for (int t = 0; t< dimensions; t++) {
                straight += bingos[j][t] + "|";
            }
            System.out.println(straight);
            straight = "";
        }
        
    }
    public static void main(String[] args) {
        int dimension = 0;
        while (true) {

            Scanner a = new Scanner(System.in);
            System.out.println("Type the number(more tha two)");
            dimension  = a.nextInt();
            if(dimension <= 2) {
                System.out.println("Error please type again");
            } else {
                break;
            }
        }
        
        String[][] bingo = new String[dimension][dimension];
        for (int i = 0; i< dimension; i++) {
            for (int j = 0; j< dimension; j++) {
                
                bingo[i][j] = "_";
            }
        }
        board(bingo, dimension);
        int turn = 1;
        int match = 0;
        int play_count = 0;
        Scanner b = new Scanner(System.in);
        int row_1 = 0;
        int column_1 = 0;
        int row_2 = 0;
        int column_2 = 0;
        String[] check_diag = new String[dimension];
        String[] check_reverse = new String[dimension];
        String[] check_row = new String[dimension];
        String[] check_column = new String[dimension];
        while (true) {
            System.out.println("Play no." + (play_count+1));
            if (turn == 1) {
                System.out.println("Currently player: 1");
                row_1 = b.nextInt();
                column_1 = b.nextInt();
                if (!bingo[row_1 -1][column_1 - 1].equals("_")) {
                    System.out.println("Space is not empty. Try again");
                    turn = 1;
                }
                else {
                    bingo[(row_1)-1][(column_1)-1] = "O";
                    board(bingo, dimension);
                    turn = 2;
                }
            } else if (turn == 2) {
                System.out.println("Currently player: 2");
                row_2 = b.nextInt();
                column_2 = b.nextInt();
                if (!bingo[row_2 -1][column_2 - 1].equals("_")) {
                    System.out.println("Space is not empty. Try again");
                    turn = 2;
                }
                else {
                    bingo[row_2-1][column_2-1] = "X";
                    board(bingo, dimension);
                    turn = 1;
                }
            }
            for (int i = 0; i<dimension; i++) {
                check_diag[i] = bingo[i][i];
                check_reverse[i] = bingo[dimension-i-1][i];
                for (int j = 0; j<dimension; j++) {
                    check_row[i] = bingo[i][j];
                    check_column[i] = bingo[j][i];
                }
                if (Arrays.equals(check_row, new String[]{"O"})) {
                    System.out.println("Player 1 wins!");
                    turn = 0;
                } else if (Arrays.equals(check_column, new String[]{"X"})) {
                    System.out.println("Player 2 wins!");
                    turn = 0;
                }
                for (int d = 0; d< dimension; d++) {
                    check_row[d] = "";
                }
            
                if (Arrays.equals(check_column, new String[]{"O"})) {
                    System.out.println("Player 1 wins!");
                    turn = 0;
                } else if (Arrays.equals(check_column, new String[]{"X"})) {
                    System.out.println("Player 2 wins!");
                    turn = 0;
                }
                for (int g = 0; g< dimension; g++) {
                    check_column[g] = "";
                }

            }
            if (Arrays.equals(check_diag, new String[]{"O"}) || Arrays.equals(check_reverse, new String[]{"X"}) ) {
                System.out.println("Player 1 wins!");
                turn = 0;
            } else if (Arrays.equals(check_reverse, new String[]{"O"}) || Arrays.equals(check_diag, new String[]{"X"})) {
                System.out.println("Player 2 wins!");
                turn = 0;
            }
            play_count += 1;
            if (turn == 0 || play_count == dimension*dimension) {
                System.out.println("FInish");
                break;
            }
        }
    } 
}
Bingo.main(null);
// def board(bingo, dimension):
//     for i in range(dimension):
//         print(' _', end = '')
//     for i in range(dimension):
//         print()
//         print('|', end = '')
//         for j in range(dimension):
//             print(bingo[i][j] + '|', end = '')
//     print()


// while True:
//     dimension = int(input("Please input the size of the game board(more than 2): "))
//     if dimension <= 2 :
//         print('[Error] try again')
//     else:
//         break

// bingo = [['_']*dimension for i in range(dimension)]
// board(bingo, dimension)

// turn = 1
// play_count = 0
// while True:
//     print('<Play no.{}>'.format(play_count+1))
//     if turn == 1:
//         print('Currently player: 1')
//         row_1 = int(input('Which row?(start with 1)'))
//         column_1 = int(input('Which column?(start with 1)'))

//         if bingo[row_1-1][column_1-1] != '_':
//             print('Space is not empty. Try again')
//             turn = 1
//             continue
//         else:
//             bingo[row_1-1][column_1-1] = 'O'
//             board(bingo,dimension)
//             turn = 2

//     elif turn == 2:
//         print('Currently player: 2')
//         row_2 = int(input('Which row?(start with 1) '))
//         column_2 = int(input('Which column?(start with 1) '))

//         if bingo[row_2-1][column_2-1] != '_':
//             print('Space is not empty. Try again')
//             turn = 2
//             continue
//         else:
//             bingo[row_2-1][column_2-1] = 'X'
//             board(bingo,dimension)
//             turn = 1

//     check_diag = []
//     check_reverse = []
//     check_row = []
//     check_column =[]
            
//     for i in range(dimension):
//         check_diag.append(bingo[i][i])
//         check_reverse.append(bingo[dimension-i-1][i])
        

//         for j in range(dimension):
//             check_row.append(bingo[i][j])
//             check_column.append(bingo[j][i])
        
//         if set(check_row) == {'O'}:
//             print('Player 1 wins!')
//             turn = 0
//         elif set(check_row) == {'X'}:
//             print('Player 2 wins!')
//             turn = 0

//         check_row = []

//         if set(check_column) == {'O'}:
//             print('Player 1 wins!')
//             turn = 0
//         elif set(check_column) == {'X'}:
//             print('Player 2 wins!')
//             turn = 0
//         check_column = []

//     check_diag = set(check_diag)
//     check_reverse = set(check_reverse)

//     if check_diag == {'O'} or check_reverse == {'O'}:
//         print('Player 1 wins!')
//         turn = 0
        
//     elif check_diag == {'X'} or check_reverse == {'X'}:
//         print('Player 2 wins!')
//         turn = 0

//     play_count += 1


//     if turn == 0 or play_count == dimension**2:
//         print('Finish')
//         break
// Out:
// Type the number(more tha two)
//  _ _ _
// |_|_|_|
// |_|_|_|
// |_|_|_|
// Play no.1
// Currently player: 1
//  _ _ _
// |O|_|_|
// |_|_|_|
// |_|_|_|
// Play no.2
// Currently player: 2
//  _ _ _
// |O|_|_|
// |_|_|X|
// |_|_|_|
// Play no.3
// Currently player: 1
//  _ _ _
// |O|_|_|
// |_|O|X|
// |_|_|_|
// Play no.4
// Currently player: 2
//  _ _ _
// |O|_|_|
// |_|O|X|
// |X|_|_|
// Play no.5
// Currently player: 1
//  _ _ _
// |O|_|_|
// |_|O|X|
// |X|_|O|
// Play no.6
// Currently player: 2
//  _ _ _
// |O|_|_|
// |_|O|X|
// |X|X|O|
// Play no.7
// Currently player: 1
//  _ _ _
// |O|O|_|
// |_|O|X|
// |X|X|O|
// Play no.8
// Currently player: 2
//  _ _ _
// |O|O|_|
// |X|O|X|
// |X|X|O|
// Play no.9
// Currently player: 1
//  _ _ _
// |O|O|O|
// |X|O|X|
// |X|X|O|
// FInish
